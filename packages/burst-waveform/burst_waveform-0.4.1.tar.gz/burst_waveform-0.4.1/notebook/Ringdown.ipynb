# %%
from burst_waveform.models import Ringdown
from matplotlib import pyplot as plt

params = {
    "tau": 0.3,
    "frequency": 1000.0,
    "iota": 45.0,
}

model = Ringdown(params)
hp, hc = model()

plt.plot(hp)
plt.plot(hc)
plt.show()
# Out:
# /Users/yumengxu/miniforge3/envs/waveform/lib/python3.11/site-packages/gwpy/time/__init__.py:36: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   from lal import LIGOTimeGPS

# %%
# read /Users/yumengxu/object_data.txt and plot the data
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('/Users/yumengxu/f1000_t0d3_p45_hp.txt')
plt.plot(hp)
plt.plot(hp.times, data)
plt.plot(hp.times, hp - data)
print(np.max(np.abs((hp - data))))
plt.show()
# Out:
# 4.99226842443079e-06

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('/Users/yumengxu/f1000_t0d3_p45_hc.txt')
plt.plot(hc)
plt.plot(hc.times, data)
plt.plot((hc - data))
print(np.max(np.abs((hc - data))))
plt.show()
# Out:
# 4.999615570433491e-06
